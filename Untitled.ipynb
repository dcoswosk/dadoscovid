# %%
import pandas as pd

# %%
dados = pd.read_csv("Downloads/MICRODADOS.csv", encoding='latin-1', sep=";", low_memory=False)
dados.head()
# Out:
#   DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0      2023-03-27   2023-03-27      2023-03-22               NaN
# 1      2023-03-27   2023-03-27      2023-03-27               NaN
# 2      2023-03-27   2023-03-27      2023-03-25               NaN
# 3      2023-03-27   2023-03-27      2023-03-26               NaN
# 4      2023-03-27   2023-03-27      2023-03-25               NaN
#
#   DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0                   NaN                 NaN                    NaN
# 1            2023-03-27                 NaN                    NaN
# 2            2023-03-27                 NaN                    NaN
# 3            2023-03-26                 NaN                    NaN
# 4            2023-03-27                 NaN                    NaN
#
#   DataEncerramento DataObito Classificacao          ...            \
# 0              NaN       NaN      Suspeito          ...
# ...

# %%
query = dados.query('Municipio == "CARIACICA" & ComorbidadeTabagismo == "Sim" & DataObito > "2019" & Evolucao == "Óbito pelo COVID-19"')
query[['Municipio', 'ComorbidadeTabagismo', 'DataObito', 'Evolucao']]
# Out:
#          Municipio ComorbidadeTabagismo   DataObito             Evolucao
# 118739   CARIACICA                  Sim  2023-01-10  Óbito pelo COVID-19
# 694661   CARIACICA                  Sim  2022-07-14  Óbito pelo COVID-19
# 803863   CARIACICA                  Sim  2022-01-23  Óbito pelo COVID-19
# 817572   CARIACICA                  Sim  2022-07-15  Óbito pelo COVID-19
# 977541   CARIACICA                  Sim  2022-06-29  Óbito pelo COVID-19
# 1429793  CARIACICA                  Sim  2022-02-28  Óbito pelo COVID-19
# 1716274  CARIACICA                  Sim  2022-02-06  Óbito pelo COVID-19
# 1780381  CARIACICA                  Sim  2022-02-10  Óbito pelo COVID-19
# 2118507  CARIACICA                  Sim  2022-01-20  Óbito pelo COVID-19
# 2369028  CARIACICA                  Sim  2021-12-30  Óbito pelo COVID-19
# 2589705  CARIACICA                  Sim  2021-11-02  Óbito pelo COVID-19
# 2598183  CARIACICA                  Sim  2021-11-02  Óbito pelo COVID-19
# ...
